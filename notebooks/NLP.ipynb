# %% [markdown]
# # NLP

# %% [markdown]
# **Which of the following techniques can be used for the purpose of keyword normalization, the process of converting a keyword into its base form?**
#
# Eg: saddest, sadden, sadly -> sad

# %%
import nltk
from nltk.stem.wordnet import WordNetLemmatizer 
from nltk.stem.porter import PorterStemmer

nltk.download('wordnet')
word = "studying"
word1 = "studies"
print(WordNetLemmatizer().lemmatize(word), PorterStemmer().stem(word))
WordNetLemmatizer().lemmatize(word1), PorterStemmer().stem(word1)
# Out:
# studying studi
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/mageswarand/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ('study', 'studi')

# %% [markdown]
# **N-grams are defined as the combination of N keywords together. How many bi-grams can be generated from given sentence:**

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/mageswarand/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize

sentence = "one two three four five six seven eight nine ten"
list(nltk.bigrams(word_tokenize(sentence)))
# Out:
# [('one', 'two'),
#  ('two', 'three'),
#  ('three', 'four'),
#  ('four', 'five'),
#  ('five', 'six'),
#  ('six', 'seven'),
#  ('seven', 'eight'),
#  ('eight', 'nine'),
#  ('nine', 'ten')]

# %% [markdown]
# **We have 100K of tweets and we wanted to categorize each of the tweets in three buckets - positive, negative and neutral**
# **Which of the following models can perform tweet classification with regards to context mentioned above?**
#
# - Naive Bayes
# - SVM
# - **None of these**

# %% [markdown]
# **In Latent Dirichlet Allocation model for text classification purposes, what does alpha and beta hyper-parameter represent-**
#
# https://datascience.stackexchange.com/questions/199/what-does-the-alpha-and-beta-hyperparameters-contribute-to-in-latent-dirichlet-a

# %% [markdown]
# **In a corpus of N documents, one document is randomly picked. The document contains a total of T terms and the term “data” appears K times.
# What is the correct value for the product of TF (term frequency) and IDF (inverse-document-frequency), if the term “data” appears in approximately one-third of the total documents?**
#
# ![image.png](attachment:2b08150e-8117-483a-87db-d68db37cf3b6.png)
#
# TF = K / T
# [ K number of time term ‘data’ appeared / Total # of term in doc ]
# IDF = log(N / (N/3)) → log(3)
# [ N document / Number of document with term ‘data’ ]
#
# K * Log(3) / K
